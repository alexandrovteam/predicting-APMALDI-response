# %%
from pathlib import Path

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('dark_background')

# %%
import scipy.stats
from sklearn.metrics import mean_squared_error

plots_dir = Path.cwd() / "../plots"
results_dir = Path.cwd() / "../results/intensity_classification_per_mol"

# %% [markdown]
# ## Evaluation of classification

# %%
# result_filename = "intensity_classification_all_feat.csv"
# result_filename = "intensity_classification_fingerprints_feat.csv"
result_filename = "intensity_classification_mol_feat.csv"
# result_filename = "intensity_classification_one_random_mol_feat.csv"

detection_results = pd.read_csv(results_dir / result_filename, index_col = 0)
detection_results = detection_results.rename(columns={'Matrix short': 'matrix',
                                                      'Polarity': 'polarity'})
detection_results
# Out:
#      observed_value  prediction    classifier                    name_short  \
# 0                 2           2  Logistic_reg            2-Oxoglutaric acid
# 1                 1           2  Logistic_reg     3-Hydroxyanthranilic acid
# 2                 0           2  Logistic_reg  3-Hydroxymethylglutaric acid
# 3                 3           2  Logistic_reg        3-Phosphoglyceric acid
# 4                 3           2  Logistic_reg        4,5-Dihydroorotic acid
# ..              ...         ...           ...                           ...
# 107               1           1           MLP                      Xanthine
# 108               1           0           MLP              alpha-tocopherol
# 109               1           0           MLP             cis-Aconitic acid
# 110               1           1           MLP       gamma-Aminobutyric acid
# 111               1           1           MLP                  myo-Inositol
#
#     matrix  polarity  fold
# 0      9AA  negative     0
# 1      9AA  negative     0
# 2      9AA  negative     0
# 3      9AA  negative     0
# 4      9AA  negative     0
# ..     ...       ...   ...
# 107    pNA  positive     9
# 108    pNA  positive     9
# 109    pNA  positive     9
# 110    pNA  positive     9
# 111    pNA  positive     9
#
# [23660 rows x 7 columns]

# %% [markdown]
#     ### Add baseline classifier
# Randomly predict detected/not-detected, based on the detected probability for each matrix/polarity:

# %%
baseline_results = detection_results.drop(columns=["classifier", "prediction", "fold"]).drop_duplicates().reset_index(drop=True)
baseline_results["prediction"] = 0
baseline_results["fold"] = 0
baseline_results["classifier"] = "random_guess"

for (matrix, polarity), rows in baseline_results.groupby(['matrix', 'polarity']):
    detected_prob = float(rows["observed_value"].sum()) / len(rows)
    prediction = (np.random.random(size=len(rows)) < detected_prob).astype('int')
    baseline_results.loc[rows.index.to_list(), "prediction"] = prediction

detection_results = pd.concat([detection_results, baseline_results])

# %%
baseline_results
# Out:
#       observed_value                    name_short matrix  polarity  \
# 0                  2            2-Oxoglutaric acid    9AA  negative
# 1                  1     3-Hydroxyanthranilic acid    9AA  negative
# 2                  0  3-Hydroxymethylglutaric acid    9AA  negative
# 3                  3        3-Phosphoglyceric acid    9AA  negative
# 4                  3        4,5-Dihydroorotic acid    9AA  negative
# ...              ...                           ...    ...       ...
# 3375               1                      Xanthine    pNA  positive
# 3376               1              alpha-tocopherol    pNA  positive
# 3377               1             cis-Aconitic acid    pNA  positive
# 3378               1       gamma-Aminobutyric acid    pNA  positive
# 3379               1                  myo-Inositol    pNA  positive
#
#       prediction  fold    classifier
# 0              1     0  random_guess
# 1              1     0  random_guess
# 2              1     0  random_guess
# 3              1     0  random_guess
# 4              1     0  random_guess
# ...          ...   ...           ...
# 3375           1     0  random_guess
# 3376           1     0  random_guess
# 3377           1     0  random_guess
# 3378           1     0  random_guess
# 3379           1     0  random_guess
#
# [3380 rows x 7 columns]

# %% [markdown]
# ### Compute metrics

# %%
from sklearn.metrics import classification_report

score_cols = ['not_det_precision', 'not_det_recall', 'not_det_f1', 'not_detected',
                                            'det_precision', 'det_recall', 'det_f1', 'detected', 'macro_avg_f1_score']

detection_metrics = pd.DataFrame(columns = ['matrix', 'polarity', 'classifier'] + score_cols)

counter = 0
for (matrix, polarity, classifier), rows in detection_results.groupby(['matrix', 'polarity', 'classifier']):
    clf_report = classification_report(rows.observed_value, rows.prediction, output_dict = True, zero_division=0)
    if rows.observed_value.max() == 0:
        print("no detection!")
    detection_metrics.loc[counter] = [matrix, polarity, classifier,
                                      clf_report['0']['precision'], clf_report['0']['recall'],
                                      clf_report['0']['f1-score'], clf_report['0']['support'],
                                      clf_report['1']['precision'], clf_report['1']['recall'],
                                      clf_report['1']['f1-score'], clf_report['1']['support'],
                                      clf_report['macro avg']['f1-score']
                                      ]
    counter += 1

# %%
best_det_f1 = detection_metrics.loc[detection_metrics.groupby(['matrix', 'polarity'])["det_f1"].idxmax()].sort_values("macro_avg_f1_score", ascending=False)

best_det_f1[["matrix", "polarity",
             "classifier",
             # "not_det_f1",
             # "det_f1",
             "macro_avg_f1_score",
             "not_detected",
             "detected"
             ]]
# best_det_f1[["matrix", "polarity",  "det_f1", "classifier"]]
# best_det_f1["det_f1"].mean()
# best_det_f1
# Out:
#     matrix  polarity    classifier  macro_avg_f1_score  not_detected  detected
# 45   ClCCA  negative           MLP            0.792383           136        33
# 101   NEDC  negative           MLP            0.759297           136        33
# 4      9AA  negative  RandomForest            0.519704            50        57
# 57     DAN  negative    KNeighbors            0.479436            60        83
# 31    CMBT  negative           MLP            0.466184           141        27
# 25    CHCA  positive  RandomForest            0.457508            25        87
# 40    CMBT  positive      SVC_poly            0.440744            62        85
# 18    CHCA  negative  RandomForest            0.409294           110        46
# 87     DHB  negative           MLP            0.408206           113        46
# 10     9AA  positive           MLP            0.401732           112        40
# 80    DHAP  positive           MLP            0.385928            72        83
# 126    pNA  negative  DecisionTree            0.380996            83        79
# 68     DAN  positive      SVC_poly            0.377749            64        86
# 97     DHB  positive       SVC_rbf            0.362450            20       100
# 110   NEDC  positive      SVC_poly            0.344565           130        37
# 53   ClCCA  positive  RandomForest            0.331455            36       109
# 136    pNA  positive           MLP            0.320035            57        83
# 122    NOR  positive           MLP            0.311620            78        63
# 115    NOR  negative           MLP            0.310973            59        67
# 76    DHAP  negative       SVC_rbf            0.303357           107        56

# %%
fig, axes = plt.subplots(ncols=4,nrows=5, sharey=True, figsize= (20, 35))
ax_list = axes.flat

metric = "macro_avg_f1_score"
#metric = "RMSE"

i = 0
for (matrix, polarity), rows in detection_metrics.groupby(['matrix', 'polarity']):
    rows = rows.set_index('classifier', drop = True).sort_values( by = metric)
    rows[metric].plot.bar(ax = ax_list[i], title=f"{matrix}-{polarity}")
    ax_list[i].set_ylabel(metric)
    ax_list[i].grid(axis='y')
    i+=1

plt.subplots_adjust(hspace=0.5)

plt.show()

plots_f1_score = plots_dir / "macro_avg_f1_score"
plots_f1_score.mkdir(exist_ok=True)
fig.savefig(plots_f1_score / result_filename.replace(".csv", ".pdf"))

# %% [markdown]
# ### Find best model according to avg-f1

# %%
# FInd best model across matrices:
metric = "macro_avg_f1_score"
classifier_performance = pd.DataFrame()

for (matrix, polarity), rows in detection_metrics.groupby(['matrix', 'polarity']):
    rows["difference"] = rows[metric] - rows[metric].max()
    classifier_performance = pd.concat([classifier_performance, rows[["classifier", "difference"]]])

classifier_performance = classifier_performance.groupby(["classifier"]).mean()
classifier_performance.sort_values("difference", ascending=False)
# Out:
#               difference
# classifier
# MLP            -0.027207
# RandomForest   -0.035817
# SVC_poly       -0.037448
# SVC_rbf        -0.039761
# DecisionTree   -0.062985
# KNeighbors     -0.063138
# Logistic_reg   -0.081091

# %% [markdown]
# ### Std of scores over folds:

# %%
from sklearn.metrics import classification_report

detection_metrics_over_fold = pd.DataFrame(columns = ['matrix', 'polarity', 'classifier', 'fold'] + score_cols)

counter = 0
for (matrix, polarity, classifier, fold), rows in detection_results.groupby(['matrix', 'polarity', 'classifier', 'fold']):
    clf_report = classification_report(rows.observed_value, rows.prediction, output_dict = True, zero_division=0)
    if rows.observed_value.max() == 0:
        print("no detection! Aborting")
        break
    detection_metrics_over_fold.loc[counter] = [matrix, polarity, classifier, fold,
                                      clf_report['0']['precision'], clf_report['0']['recall'],
                                      clf_report['0']['f1-score'], clf_report['0']['support'],
                                      clf_report['1']['precision'], clf_report['1']['recall'],
                                      clf_report['1']['f1-score'], clf_report['1']['support'],
                                      clf_report['macro avg']['f1-score']
                                      ]
    counter += 1

# Now compute std over folds:
detection_metrics_over_fold = detection_metrics_over_fold.groupby(['matrix', 'polarity', 'classifier'], as_index=False)[score_cols].std()
# Out:
#     matrix  polarity classifier  not_det_precision  not_det_recall  \
# 3      9AA  negative        MLP           0.188702        0.146734
# 10     9AA  positive        MLP           0.080125        0.107709
# 17    CHCA  negative        MLP           0.092725        0.122856
# 24    CHCA  positive        MLP           0.311948        0.335640
# 31    CMBT  negative        MLP           0.066161        0.115705
# 38    CMBT  positive        MLP           0.141696        0.177221
# 45   ClCCA  negative        MLP           0.056970        0.077490
# 52   ClCCA  positive        MLP           0.151138        0.274986
# 59     DAN  negative        MLP           0.177639        0.178421
# 66     DAN  positive        MLP           0.162874        0.197306
# 73    DHAP  negative        MLP           0.110204        0.188523
# 80    DHAP  positive        MLP           0.142753        0.159579
# 87     DHB  negative        MLP           0.084213        0.092539
# 94     DHB  positive        MLP           0.336691        0.416111
# 101   NEDC  negative        MLP           0.072851        0.094852
# 108   NEDC  positive        MLP           0.059730        0.107394
# 115    NOR  negative        MLP           0.194437        0.168930
# 122    NOR  positive        MLP           0.117843        0.171488
# 129    pNA  negative        MLP           0.173529        0.178706
# 136    pNA  positive        MLP           0.149442        0.179471
#
#      not_det_f1  not_detected  det_precision  det_recall    det_f1  detected  \
# 3      0.104794      0.816497       0.154161    0.155754  0.116132  0.483046
# 10     0.072706      0.918937       0.135458    0.197203  0.149021  0.000000
# 17     0.086527      0.471405       0.235859    0.320416  0.250196  0.516398
# 24     0.269131      0.527046       0.222730    0.159632  0.155142  0.483046
# 31     0.074259      0.316228       0.322343    0.304797  0.269005  0.483046
# 38     0.152798      1.619328       0.150715    0.094017  0.115922  0.527046
# 45     0.049531      0.516398       0.183490    0.237171  0.182093  0.483046
# 52     0.188235      0.516398       0.111824    0.108758  0.100814  0.316228
# 59     0.143153      0.666667       0.176595    0.197181  0.152219  0.483046
# 66     0.131480      0.966092       0.195631    0.205198  0.179011  0.516398
# 73     0.138116      0.483046       0.233016    0.195757  0.191171  0.516398
# 80     0.099826      1.135292       0.115035    0.163322  0.127858  0.483046
# 87     0.071600      0.483046       0.150411    0.227058  0.184347  0.516398
# 94     0.325842      1.054093       0.124790    0.137032  0.119291  0.000000
# 101    0.044703      0.516398       0.229734    0.310441  0.182060  0.483046
# 108    0.060795      0.816497       0.281091    0.167820  0.131393  0.483046
# 115    0.175767      0.737865       0.141607    0.166023  0.140869  0.483046
# 122    0.131873      0.632456       0.161221    0.232812  0.180670  0.483046
# 129    0.146556      0.483046       0.163603    0.195832  0.172565  0.316228
# 136    0.114481      0.483046       0.100565    0.123958  0.100917  0.483046
#
#      macro_avg_f1_score
# 3              0.106233
# 10             0.112516
# 17             0.127010
# 24             0.096825
# 31             0.164502
# 38             0.129120
# 45             0.112566
# 52             0.143953
# 59             0.175809
# 66             0.144297
# 73             0.181347
# 80             0.099839
# 87             0.172915
# 94             0.085874
# 101            0.105566
# 108            0.157576
# 115            0.105156
# 122            0.186287
# 129            0.190703
# 136            0.110333

# %%
detection_metrics_over_fold[detection_metrics_over_fold.classifier == "MLP"]
# Out:
#     matrix  polarity classifier  not_det_precision  not_det_recall  \
# 3      9AA  negative        MLP           0.188702        0.146734
# 10     9AA  positive        MLP           0.080125        0.107709
# 17    CHCA  negative        MLP           0.092725        0.122856
# 24    CHCA  positive        MLP           0.311948        0.335640
# 31    CMBT  negative        MLP           0.066161        0.115705
# 38    CMBT  positive        MLP           0.141696        0.177221
# 45   ClCCA  negative        MLP           0.056970        0.077490
# 52   ClCCA  positive        MLP           0.151138        0.274986
# 59     DAN  negative        MLP           0.177639        0.178421
# 66     DAN  positive        MLP           0.162874        0.197306
# 73    DHAP  negative        MLP           0.110204        0.188523
# 80    DHAP  positive        MLP           0.142753        0.159579
# 87     DHB  negative        MLP           0.084213        0.092539
# 94     DHB  positive        MLP           0.336691        0.416111
# 101   NEDC  negative        MLP           0.072851        0.094852
# 108   NEDC  positive        MLP           0.059730        0.107394
# 115    NOR  negative        MLP           0.194437        0.168930
# 122    NOR  positive        MLP           0.117843        0.171488
# 129    pNA  negative        MLP           0.173529        0.178706
# 136    pNA  positive        MLP           0.149442        0.179471
#
#      not_det_f1  not_detected  det_precision  det_recall    det_f1  detected  \
# 3      0.104794      0.816497       0.154161    0.155754  0.116132  0.483046
# 10     0.072706      0.918937       0.135458    0.197203  0.149021  0.000000
# 17     0.086527      0.471405       0.235859    0.320416  0.250196  0.516398
# 24     0.269131      0.527046       0.222730    0.159632  0.155142  0.483046
# 31     0.074259      0.316228       0.322343    0.304797  0.269005  0.483046
# 38     0.152798      1.619328       0.150715    0.094017  0.115922  0.527046
# 45     0.049531      0.516398       0.183490    0.237171  0.182093  0.483046
# 52     0.188235      0.516398       0.111824    0.108758  0.100814  0.316228
# 59     0.143153      0.666667       0.176595    0.197181  0.152219  0.483046
# 66     0.131480      0.966092       0.195631    0.205198  0.179011  0.516398
# 73     0.138116      0.483046       0.233016    0.195757  0.191171  0.516398
# 80     0.099826      1.135292       0.115035    0.163322  0.127858  0.483046
# 87     0.071600      0.483046       0.150411    0.227058  0.184347  0.516398
# 94     0.325842      1.054093       0.124790    0.137032  0.119291  0.000000
# 101    0.044703      0.516398       0.229734    0.310441  0.182060  0.483046
# 108    0.060795      0.816497       0.281091    0.167820  0.131393  0.483046
# 115    0.175767      0.737865       0.141607    0.166023  0.140869  0.483046
# 122    0.131873      0.632456       0.161221    0.232812  0.180670  0.483046
# 129    0.146556      0.483046       0.163603    0.195832  0.172565  0.316228
# 136    0.114481      0.483046       0.100565    0.123958  0.100917  0.483046
#
#      macro_avg_f1_score
# 3              0.106233
# 10             0.112516
# 17             0.127010
# 24             0.096825
# 31             0.164502
# 38             0.129120
# 45             0.112566
# 52             0.143953
# 59             0.175809
# 66             0.144297
# 73             0.181347
# 80             0.099839
# 87             0.172915
# 94             0.085874
# 101            0.105566
# 108            0.157576
# 115            0.105156
# 122            0.186287
# 129            0.190703
# 136            0.110333
